# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanusi-Habeeb-Eniola/Sanusi-Habeeb-Eniola.github.io/blob/main/Retail_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e0134ea-91c1-4bdb-92cd-88f1992879d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e0134ea-91c1-4bdb-92cd-88f1992879d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("retail_sales_dataset.csv")

print(df.shape)

df.head()
# Out:
# (1000, 9)
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.isnull()
# Out:
#      Transaction ID   Date  Customer ID  Gender    Age  Product Category  \
# 0             False  False        False   False  False             False
# 1             False  False        False   False  False             False
# 2             False  False        False   False  False             False
# 3             False  False        False   False  False             False
# 4             False  False        False   False  False             False
# ..              ...    ...          ...     ...    ...               ...
# 995           False  False        False   False  False             False
# 996           False  False        False   False  False             False
# 997           False  False        False   False  False             False
# 998           False  False        False   False  False             False
# 999           False  False        False   False  False             False
#
#      Quantity  Price per Unit  Total Amount
# 0       False           False         False
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
df.describe(include="all")
# Out:
#         Transaction ID        Date Customer ID  Gender         Age  \
# count      1000.000000        1000        1000    1000  1000.00000
# unique             NaN         345        1000       2         NaN
# top                NaN  2023-05-16    CUST1000  Female         NaN
# freq               NaN          11           1     510         NaN
# mean        500.500000         NaN         NaN     NaN    41.39200
# std         288.819436         NaN         NaN     NaN    13.68143
# min           1.000000         NaN         NaN     NaN    18.00000
# 25%         250.750000         NaN         NaN     NaN    29.00000
# 50%         500.500000         NaN         NaN     NaN    42.00000
# 75%         750.250000         NaN         NaN     NaN    53.00000
# max        1000.000000         NaN         NaN     NaN    64.00000
#
#        Product Category     Quantity  Price per Unit  Total Amount
# count              1000  1000.000000     1000.000000   1000.000000
# ...

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.rename(columns={"Total Amount":"Amount"})
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Amount
# 0           3              50     150
# ...

# %%
df['Total Amount'].mean()
# Out:
# np.float64(456.0)

# %%
df["Total Amount"].median()
# Out:
# 135.0

# %%
df["Total Amount"].mode()
# Out:
# 0    50
# Name: Total Amount, dtype: int64

# %%
df["Total Amount"].std()
# Out:
# 559.997631555123

# %%
df.groupby("Gender")["Total Amount"].sum()
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
df.groupby("Product Category")["Total Amount"].sum()
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
total_revenue = df["Total Amount"].sum()
print(total_revenue)
# Out:
# 456000

# %%
Most_popular_product = df["Product Category"].mode()
print(Most_popular_product)
# Out:
# 0    Clothing
# Name: Product Category, dtype: object

# %%
most_purchased_product = df.groupby("Product Category")["Quantity"].sum().idxmax()
print(most_purchased_product)
# Out:
# Clothing

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %%
sales_trend = df.groupby('Month')['Total Amount'].sum()
sales_trend.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %%
df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount     Month
# 0         3              50           150  November
# 1         2             500          1000  February
# 2         1              30            30   January
# 3         1             500           500       May
# 4         2              50           100       May

# %%
df["Month"] = df['Date'].dt.month_name()

# %%
sales_trend = df.groupby('Month')['Total Amount'].sum().sort_index()
sales_trend.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %%
df = df.sort_values(by='Month')

# %%
df = df.sort_values(by='Date')

# %%
month_order = [
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
]

# %%
df['Month'] = pd.Categorical(df['Month'], categories=month_order, ordered=True)

# %%
df.head()
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 179             180 2023-01-01     CUST180    Male   41         Clothing
# 558             559 2023-01-01     CUST559  Female   40         Clothing
# 521             522 2023-01-01     CUST522    Male   46           Beauty
# 420             421 2023-01-02     CUST421  Female   37         Clothing
# 302             303 2023-01-02     CUST303    Male   19      Electronics
#
#      Quantity  Price per Unit  Total Amount    Month
# 179         3             300           900  January
# 558         4             300          1200  January
# 521         3             500          1500  January
# 420         3             500          1500  January
# 302         3              30            90  January

# %%
df = df.sort_values('Month')

# %%
monthly_sum = (
    df.groupby('Month')['Total Amount']
      .sum()
      .reindex(month_order)
)
# Out:
# /tmp/ipython-input-587272971.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Month')['Total Amount']

# %%
print(monthly_sum)
# Out:
# Month
# January      36980
# February     44060
# March        28990
# April        33870
# May          53150
# June         36715
# July         35465
# August       36960
# September    23620
# October      46580
# November     34920
# December     44690
# Name: Total Amount, dtype: int64

# %%
sales_trend = df.groupby('Month')['Total Amount'].sum().sort_index()
sales_trend.plot(kind='line')
# Out:
# /tmp/ipython-input-3889534910.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales_trend = df.groupby('Month')['Total Amount'].sum().sort_index()
# <Axes: xlabel='Month'>

# %%
df.head()
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 179             180 2023-01-01     CUST180    Male   41         Clothing
# 591             592 2023-01-24     CUST592  Female   46           Beauty
# 63               64 2023-01-24     CUST064    Male   49         Clothing
# 911             912 2023-01-24     CUST912    Male   51           Beauty
# 48               49 2023-01-23     CUST049  Female   54      Electronics
#
#      Quantity  Price per Unit  Total Amount    Month
# 179         3             300           900  January
# 591         4             500          2000  January
# 63          4              25           100  January
# 911         3              50           150  January
# 48          2             500          1000  January

# %%
top_product_category = df.groupby('Product Category')['Total Amount'].sum().idxmax()
print(top_product_category)
# Out:
# Electronics

# %%
gender_sales = df.groupby('Gender')['Total Amount'].sum()
gender_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
product_sales = df.groupby('Product Category')['Total Amount'].sum()
product_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Product Category'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sales by Category
sns.barplot(x='Product Category', y='Total Amount', data=df)

# Heatmap for correlation
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df['Total Amount'].sum
# Out:
# <bound method Series.sum of 179     900
# 591    2000
# 63      100
# 911     150
# 48     1000
#        ...
# 391     600
# 452    1000
# 539     900
# 79       60
# 751     100
# Name: Total Amount, Length: 1000, dtype: int64>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 179 to 751
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
#  9   Month             1000 non-null   category
# dtypes: category(1), datetime64[ns](1), int64(5), object(3)
# memory usage: 79.5+ KB

# %%
df.head()
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 179             180 2023-01-01     CUST180    Male   41         Clothing
# 591             592 2023-01-24     CUST592  Female   46           Beauty
# 63               64 2023-01-24     CUST064    Male   49         Clothing
# 911             912 2023-01-24     CUST912    Male   51           Beauty
# 48               49 2023-01-23     CUST049  Female   54      Electronics
#
#      Quantity  Price per Unit  Total Amount    Month
# 179         3             300           900  January
# 591         4             500          2000  January
# 63          4              25           100  January
# 911         3              50           150  January
# 48          2             500          1000  January

# %%
df.groupby("Product Category")["Quantity"].sum()
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64
